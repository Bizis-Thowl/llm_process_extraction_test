# %%
# !!! These lines should be executed in the bash directly !!!
# Initialize environment
! graphrag init
# Starting the indexing
! graphrag index

# %%
! graphrag query "What are the top themes in this story?"
# Out:
# # Top Themes in *A Christmas Carol*
#
# The story of *A Christmas Carol* by Charles Dickens is a rich tapestry of interconnected themes, each explored through the transformation of Ebenezer Scrooge and the broader social commentary embedded in the narrative. The following sections synthesize the key themes identified by analysts, supported by data references from the dataset.
#
# ---
#
# ## 1. **Redemption and Moral Transformation**
# The central theme of the story revolves around Scrooge’s journey from a miserly, self-centered individual to a compassionate and generous person. This transformation is driven by supernatural encounters with the Ghosts of Christmas Past, Present, and Future, which expose the consequences of his greed and isolation. Analysts emphasize that Scrooge’s redemption is not merely a personal awakening but a moral reckoning with his past actions, including his neglect of a child at his school and his harsh treatment of Bob Cratchit. The narrative underscores the power of self-reflection, empathy, and the capacity for change, even in the face of entrenched selfishness.
#
# **Key elements**:
# - The Ghosts of Christmas Past, Present, and Future serve as catalysts for Scrooge’s moral awakening, revealing the impact of his choices on others. [Data: Reports (19, 28, 26, 11), (36, 5, 9, 20, 7, +more)]
# - Scrooge’s reconciliation with his nephew Fred and the Cratchit family symbolizes his shift from isolation to community. [Data: Reports (15, 4, 8, 10, 16, +more)]
# - The Cratchit family’s resilience and their celebration of Christmas contrast sharply with Scrooge’s initial miserliness, highlighting the transformative power of compassion. [Data: Reports (3, 24, 6, 1, 27, 37)]
#
# ---
#
# ## 2. **The Role of Supernatural Elements**
# The supernatural elements in the story—particularly the Ghosts of Christmas—play a pivotal role in driving Scrooge’s transformation. These entities are not mere figments of imagination but symbolic representations of moral accountability, the weight of past actions, and the potential for redemption. The Ghost of Christmas Past forces Scrooge to confront his lonely childhood and the moments of kindness he once ignored. The Ghost of Christmas Present reveals the suffering of the poor and the interconnectedness of human lives, while the Ghost of Christmas Yet to Come warns of the consequences of his current behavior.
#
# **Key elements**:
# - The supernatural encounters are structured to escalate Scrooge’s awareness of his moral failures, culminating in his willingness to change. [Data: Reports (19, 28, 26, 11), (36, 5, 9, 20, 7, +more)]
# - Marley’s ghost, bound by chains of greed, serves as a warning of the inescapability of moral consequences. [Data: Reports (37, 24, 6)]
# - The Ghost of Christmas Present’s depiction of the Cratchit family’s struggles underscores the theme of social inequality and the moral duty to care for others. [Data: Reports (15, 4, 8, 10, 16, +more)]
#
# ---
#
# ## 3. **Community, Family, and Human Connection**
# The story emphasizes the importance of community and familial bonds as antidotes to Scrooge’s isolation. The Cratchit family’s resilience, despite their poverty, becomes a model of compassion and unity. Their festive gatherings and shared joy contrast with Scrooge’s initial miserliness, illustrating the transformative power of human connection. Analysts also highlight Scrooge’s eventual reconciliation with Fred, symbolizing the restoration of familial ties and the rejection of his former worldview.
#
# **Key elements**:
# - The Cratchit family’s celebration of Christmas, despite their financial struggles, embodies the spirit of generosity and hope. [Data: Reports (14, 35, 13), (3, 24, 6, 1, 27, 37)]
# - Scrooge’s interactions with the community, particularly his eventual generosity toward the Cratchits and the broader population, underscore the theme of collective well-being. [Data: Reports (3, 6, 27, 30)]
# - The story critiques the dehumanizing effects of wealth and isolation, advocating for a society built on empathy and shared responsibility. [Data: Reports (15, 4, 8, 10, 16, +more)]
#
# ---
#
# ## 4. **Social Critique and Economic Inequality**
# Beyond the personal transformation of Scrooge, the story critiques systemic failures in society, particularly the treatment of the poor and the inequities of economic structures. Analysts note that Scrooge’s views on poverty, as reflected in his disdain for the Poor Law and the Treadmill system, mirror the broader societal attitudes of the time. The narrative exposes the moral failures of institutions that perpetuate suffering, such as the Union Workhouses, and calls for reform through compassion and social responsibility.
#
# **Key elements**:
# - The Poor Law and Treadmill system are depicted as mechanisms that trap the poor in cycles of destitution, reflecting the story’s critique of systemic neglect. [Data: Reports (19, 28), (36, 15, 22, 2, +more)]
# - The contrast between Scrooge’s wealth and the Cratchits’ poverty highlights the moral imperative to address economic inequality. [Data: Reports (15, 10, 4, 16, +more)]
# - The story advocates for a society where individual actions—such as Scrooge’s eventual generosity—can catalyze broader social change. [Data: Reports (3, 6, 27, 30)]
#
# ---
#
# ## 5. **The Spirit of Christmas and Renewal**
# The Christmas season serves as both a backdrop and a catalyst for the story’s themes. Analysts emphasize that Christmas symbolizes renewal, forgiveness, and the possibility of redemption. The festive atmosphere, with its emphasis on generosity and community, contrasts with Scrooge’s initial isolation, ultimately leading to his transformation. The story positions Christmas not as a mere holiday but as a moral and spiritual awakening.
#
# **Key elements**:
# - The festive gatherings of the Cratchit family and the broader community embody the spirit of hope and renewal. [Data: Reports (4, 8, 16, 7, 22, +more)]
# - Scrooge’s final act of generosity, such as donating to the Cratchits and joining the festive celebrations, signifies his embrace of the Christmas spirit. [Data: Reports (15, 4, 8, 10, 16, +more)]
# - The story’s closing scenes, with Scrooge’s renewed sense of purpose, underscore the transformative power of Christmas as a season of moral reflection. [Data: Reports (26, 12, 25)]
#
# ---
#
# ## Conclusion: Interconnected Themes and Their Implications
# The themes of *A Christmas Carol* are deeply interconnected, with Scrooge’s transformation serving as a microcosm of broader societal and moral lessons. The supernatural elements, community bonds, and social critique all converge to reinforce the narrative’s central message: that compassion, empathy, and collective responsibility can overcome greed and isolation. The story’s enduring relevance lies in its ability to balance personal redemption with a call for systemic change, making it a timeless exploration of human potential for growth and renewal.
#
# **Data References**:
# - Redemption and transformation: [Reports (19, 28, 26, 11), (36, 5, 9, 20, 7, +more), (3, 24, 6, 1, 27, 37)]
# - Supernatural elements: [Reports (19, 28, 26, 11), (36, 5, 9, 20, 7, +more), (37, 24, 6)]
# - Community and family: [Reports (15, 4, 8, 10, 16, +more), (3, 24, 6, 1, 27, 37), (3, 6, 27, 30)]
# - Social critique: [Reports (19, 28), (36, 15, 22, 2, +more), (15, 10, 4, 16, +more)]
# - Christmas and renewal: [Reports (4, 8, 16, 7, 22, +more), (26, 12, 25)]
#
# This synthesis reflects the analysts’ consensus on the story’s core themes, preserving the original intent and data references while emphasizing the transformative power of morality, community, and compassion.

# %%
! graphrag query \"Who is Scrooge and what are his main relationships?"\ --method local
# Out:
# Usage: graphrag query [OPTIONS] QUERY
# Try 'graphrag query --help' for help.
# ┌─ Error ─────────────────────────────────────────────────────────────────────┐
# │ Got unexpected extra arguments (is Scrooge and what are his main            │
# │ relationships?\ --method local)                                             │
# └─────────────────────────────────────────────────────────────────────────────┘

# %%
import os
#from pathlib import Path
#from pprint import pprint

#import graphrag
import graphrag.api as api
import pandas as pd
from graphrag.config.load_config import load_config
from graphrag.index.typing.pipeline_run_result import PipelineRunResult

# %%
graphrag_config = load_config(os.getenv("PROJECT_DIRECTORY"))
PROJECT_DIRECTORY = os.getenv("PROJECT_DIRECTORY")

# %%
index_result : list[PipelineRunResult] = await api.build_index(
    config=graphrag_config,
    )
# index_result is a list of workflows that make up the indexing pipeline that was run
for workflow_result in index_result:
    status = f"error\n{workflow_result.error}" if workflow_result.error else "success"
    print(f"Workflow Name: {workflow_result.workflow}\tStatus: {status}")
# Out:
# c:\Users\qq6-xd4\Documents\Programmierung\llm_process_extraction_test\llm_process_extraction_test\.venv\Lib\site-packages\graphrag\index\operations\extract_graph\extract_graph.py:117: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_relationships = pd.concat(relationship_dfs, ignore_index=False)
# Workflow Name: load_input_documents	Status: success
# Workflow Name: create_base_text_units	Status: success
# Workflow Name: create_final_documents	Status: success
# Workflow Name: extract_graph	Status: success
# Workflow Name: finalize_graph	Status: success
# Workflow Name: extract_covariates	Status: success
# Workflow Name: create_communities	Status: success
# Workflow Name: create_final_text_units	Status: success
# Workflow Name: create_community_reports	Status: success
# Workflow Name: generate_text_embeddings	Status: success

# %%
entities = pd.read_parquet(f"{PROJECT_DIRECTORY}/output/entities.parquet")
communities = pd.read_parquet(f"{PROJECT_DIRECTORY}/output/communities.parquet")
text_unit_df = pd.read_parquet(f"{PROJECT_DIRECTORY}/output/text_units.parquet")
relationships = pd.read_parquet(f"{PROJECT_DIRECTORY}/output/relationships.parquet")
#text_units = graphrag.query.indexer_adapters.read_indexer_text_units(text_unit_df)
community_reports = pd.read_parquet(f"{PROJECT_DIRECTORY}/output/community_reports.parquet")

response, context = await api.local_search(
    config=graphrag_config,
    entities=entities,
    communities=communities,
    community_reports=community_reports,
    text_units= text_unit_df,
    relationships= relationships,
    covariates = None,
    community_level=2,
    response_type="Kurze präzise Antwort auf Deutsch",
    query="Wie heißt dieser Prozess?"
)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\main.py:5268, in embedding(model, input, dimensions, encoding_format, timeout, api_base, api_version, api_key, api_type, caching, user, custom_llm_provider, litellm_call_id, logger_fn, **kwargs)
#    5263     ollama_embeddings_fn = (
#    5264         ollama.ollama_aembeddings
#    5265         if aembedding is True
#    5266         else ollama.ollama_embeddings
#    5267     )
# -> 5268     response = ollama_embeddings_fn(  # type: ignore
#    5269         api_base=api_base,
#    5270         model=model,
#    5271         prompts=input,
#    5272         encoding=_get_encoding(),
#    5273         logging_obj=logging,
#    5274         optional_params=optional_params,
#    5275         model_response=EmbeddingResponse(),
#    5276     )
#    5277 elif custom_llm_provider == "sagemaker":
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\llms\ollama\completion\handler.py:114, in ollama_embeddings(api_base, model, prompts, optional_params, model_response, logging_obj, encoding)
#     112 data = _prepare_ollama_embedding_payload(model, prompts, optional_params)
# --> 114 response = litellm.module_level_client.post(url=api_base, json=data)
#     115 response_json = response.json()
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:1047, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#    1046 except Exception as e:
# -> 1047     raise e
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:1026, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#    1023     req = self.client.build_request(
#    1024         "POST", url, data=request_data, json=json, params=params, headers=headers, files=files, content=request_content  # type: ignore
#    1025     )
# -> 1026 response = self.client.send(req, stream=stream)
#    1027 response.raise_for_status()
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[3], line 8
#       5 #text_units = graphrag.query.indexer_adapters.read_indexer_text_units(text_unit_df)
#       6 community_reports = pd.read_parquet(f"{PROJECT_DIRECTORY}/output/community_reports.parquet")
# ----> 8 response, context = await api.local_search(
#       9     config=graphrag_config,
#      10     entities=entities,
#      11     communities=communities,
#      12     community_reports=community_reports,
#      13     text_units= text_unit_df,
#      14     relationships= relationships,
#      15     covariates = None,
#      16     community_level=2,
#      17     response_type="Kurze präzise Antwort auf Deutsch",
#      18     query="Wie heißt dieser Prozess?"
#      19 )
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\pydantic\_internal\_validate_call.py:34, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      32 @functools.wraps(wrapped)
#      33 async def wrapper_function(*args, **kwargs):  # type: ignore
# ---> 34     return await wrapper(*args, **kwargs)
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag\api\query.py:240, in local_search(config, entities, communities, community_reports, text_units, relationships, covariates, community_level, response_type, query, callbacks, verbose)
#     237 callbacks.append(local_callbacks)
#     239 logger.debug("Executing local search query: %s", query)
# --> 240 async for chunk in local_search_streaming(
#     241     config=config,
#     242     entities=entities,
#     243     communities=communities,
#     244     community_reports=community_reports,
#     245     text_units=text_units,
#     246     relationships=relationships,
#     247     covariates=covariates,
#     248     community_level=community_level,
#     249     response_type=response_type,
#     250     query=query,
#     251     callbacks=callbacks,
#     252 ):
#     253     full_response += chunk
#     254 logger.debug("Query response: %s", truncate(full_response, 400))
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag\query\structured_search\local_search\search.py:154, in LocalSearch.stream_search(self, query, conversation_history)
#     151 """Build local search context that fits a single context window and generate answer for the user query."""
#     152 start_time = time.time()
# --> 154 context_result = self.context_builder.build_context(
#     155     query=query,
#     156     conversation_history=conversation_history,
#     157     **self.context_builder_params,
#     158 )
#     159 logger.debug("GENERATE ANSWER: %s. QUERY: %s", start_time, query)
#     160 search_prompt = self.system_prompt.format(
#     161     context_data=context_result.context_chunks, response_type=self.response_type
#     162 )
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag\query\structured_search\local_search\mixed_context.py:137, in LocalSearchMixedContext.build_context(self, query, conversation_history, include_entity_names, exclude_entity_names, conversation_history_max_turns, conversation_history_user_turns_only, max_context_tokens, text_unit_prop, community_prop, top_k_mapped_entities, top_k_relationships, include_community_rank, include_entity_rank, rank_description, include_relationship_weight, relationship_ranking_attribute, return_candidate_context, use_community_summary, min_community_rank, community_context_name, column_delimiter, **kwargs)
#     132     pre_user_questions = "\n".join(
#     133         conversation_history.get_user_turns(conversation_history_max_turns)
#     134     )
#     135     query = f"{query}\n{pre_user_questions}"
# --> 137 selected_entities = map_query_to_entities(
#     138     query=query,
#     139     text_embedding_vectorstore=self.entity_text_embeddings,
#     140     text_embedder=self.text_embedder,
#     141     all_entities_dict=self.entities,
#     142     embedding_vectorstore_key=self.embedding_vectorstore_key,
#     143     include_entity_names=include_entity_names,
#     144     exclude_entity_names=exclude_entity_names,
#     145     k=top_k_mapped_entities,
#     146     oversample_scaler=2,
#     147 )
#     149 # build context
#     150 final_context = list[str]()
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag\query\context_builder\entity_extraction.py:62, in map_query_to_entities(query, text_embedding_vectorstore, text_embedder, all_entities_dict, embedding_vectorstore_key, include_entity_names, exclude_entity_names, k, oversample_scaler)
#      58 matched_entities = []
#      59 if query != "":
#      60     # get entities with highest semantic similarity to query
#      61     # oversample to account for excluded entities
# ---> 62     search_results = text_embedding_vectorstore.similarity_search_by_text(
#      63         text=query,
#      64         text_embedder=lambda t: text_embedder.embedding(input=[t]).first_embedding,
#      65         k=k * oversample_scaler,
#      66     )
#      67     for result in search_results:
#      68         if embedding_vectorstore_key == EntityVectorStoreKey.ID and isinstance(
#      69             result.document.id, str
#      70         ):
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag_vectors\vector_store.py:186, in VectorStore.similarity_search_by_text(self, text, text_embedder, k, select, filters, include_vectors)
#     176 def similarity_search_by_text(
#     177     self,
#     178     text: str,
#    (...)    183     include_vectors: bool = True,
#     184 ) -> list[VectorStoreSearchResult]:
#     185     """Perform a text-based similarity search."""
# --> 186     query_embedding = text_embedder(text)
#     187     if query_embedding:
#     188         return self.similarity_search_by_vector(
#     189             query_embedding=query_embedding,
#     190             k=k,
#    (...)    193             include_vectors=include_vectors,
#     194         )
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag\query\context_builder\entity_extraction.py:64, in map_query_to_entities.<locals>.<lambda>(t)
#      58 matched_entities = []
#      59 if query != "":
#      60     # get entities with highest semantic similarity to query
#      61     # oversample to account for excluded entities
#      62     search_results = text_embedding_vectorstore.similarity_search_by_text(
#      63         text=query,
# ---> 64         text_embedder=lambda t: text_embedder.embedding(input=[t]).first_embedding,
#      65         k=k * oversample_scaler,
#      66     )
#      67     for result in search_results:
#      68         if embedding_vectorstore_key == EntityVectorStoreKey.ID and isinstance(
#      69             result.document.id, str
#      70         ):
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag_llm\embedding\lite_llm_embedding.py:130, in LiteLLMEmbedding.embedding(self, **kwargs)
#     127     request_metrics = None
#     129 try:
# --> 130     return self._embedding(metrics=request_metrics, **kwargs)
#     131 finally:
#     132     if request_metrics:
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag_llm\middleware\with_logging.py:49, in with_logging.<locals>._request_count_middleware(**kwargs)
#      47 metrics: Metrics | None = kwargs.get("metrics")
#      48 try:
# ---> 49     return sync_middleware(**kwargs)
#      50 except Exception as e:
#      51     retries = metrics.get("retries", None) if metrics else None
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag_llm\middleware\with_request_count.py:53, in with_request_count.<locals>._request_count_middleware(**kwargs)
#      51     metrics["failed_response_count"] = 0
#      52 try:
# ---> 53     result = sync_middleware(**kwargs)
#      54     if metrics is not None:
#      55         metrics["successful_response_count"] = 1
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag_llm\middleware\with_retries.py:47, in with_retries.<locals>._retry_middleware(**kwargs)
#      44 def _retry_middleware(
#      45     **kwargs: Any,
#      46 ):
# ---> 47     return retrier.retry(
#      48         func=sync_middleware,
#      49         input_args=kwargs,
#      50     )
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag_llm\retry\exponential_retry.py:70, in ExponentialRetry.retry(self, func, input_args)
#      68 while True:
#      69     try:
# ---> 70         return func(**input_args)
#      71     except Exception as e:
#      72         if e.__class__.__name__ in self._exceptions_to_skip:
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag_llm\middleware\with_metrics.py:56, in with_metrics.<locals>._metrics_middleware(**kwargs)
#      54 metrics: Metrics | None = kwargs.get("metrics")
#      55 start_time = time.time()
# ---> 56 response = sync_middleware(**kwargs)
#      57 end_time = time.time()
#      59 if metrics is not None:
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\graphrag_llm\embedding\lite_llm_embedding.py:188, in _create_base_embeddings.<locals>._base_embedding(**kwargs)
#     185 kwargs.pop("metrics", None)  # Remove metrics if present
#     186 new_args: dict[str, Any] = {**base_args, **kwargs}
# --> 188 response = litellm.embedding(**new_args)
#     189 return LLMEmbeddingResponse(**response.model_dump())
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\utils.py:1762, in client.<locals>.wrapper(*args, **kwargs)
#    1758 if logging_obj:
#    1759     logging_obj.failure_handler(
#    1760         e, traceback_exception, start_time, end_time
#    1761     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1762 raise e
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\utils.py:1583, in client.<locals>.wrapper(*args, **kwargs)
#    1581         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1582 # MODEL CALL
# -> 1583 result = original_function(*args, **kwargs)
#    1584 end_time = datetime.datetime.now()
#    1585 if _is_streaming_request(
#    1586     kwargs=kwargs,
#    1587     call_type=call_type,
#    1588 ):
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\main.py:5707, in embedding(model, input, dimensions, encoding_format, timeout, api_base, api_version, api_key, api_type, caching, user, custom_llm_provider, litellm_call_id, logger_fn, **kwargs)
#    5701 litellm_logging_obj.post_call(
#    5702     input=input,
#    5703     api_key=api_key,
#    5704     original_response=str(e),
#    5705 )
#    5706 ## Map to OpenAI Exception
# -> 5707 raise exception_type(
#    5708     model=model,
#    5709     original_exception=e,
#    5710     custom_llm_provider=custom_llm_provider,
#    5711     extra_kwargs=kwargs,
#    5712 )
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2439, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2437 if exception_mapping_worked:
#    2438     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2439     raise e
#    2440 else:
#    2441     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File c:\Users\qq6-xd4\Documents\Programmierung\process_extraction\git\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2408, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2406 exception_mapping_worked = True
#    2407 if hasattr(original_exception, "request"):
# -> 2408     raise APIConnectionError(
#    2409         message="{} - {}".format(exception_provider, error_str),
#    2410         llm_provider=custom_llm_provider,
#    2411         model=model,
#    2412         request=getattr(original_exception, "request", None),
#    2413     )
#    2414 else:
#    2415     raise APIConnectionError(
#    2416         message="{}\n{}".format(
#    2417             str(original_exception), traceback.format_exc()
#    (...)   2423         ),  # stub the request
#    2424     )
#
# APIConnectionError: litellm.APIConnectionError: OllamaException - [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte

# %%
response
# Out:
# 'Der Prozess wird im BPMN-Diagramm als **„Dienstreiseplanung und Reisekostenabrechnung“** bezeichnet. Er umfasst Schritte wie die Planung der Dienstreise, die Prüfung des Antrags durch die Personalabteilung, die Erstellung der Reisekostenabrechnung sowie die Weiterleitung an die Buchhaltung und Rechnungsverwaltung [Daten: Sources (0), Entities (3, 6, 17), Relationships (3, 6, 15)].'

# %%
context
# Out:
# {'reports':   id                                title  \
#  0  0  Buchhaltung und Rechnungsverwaltung
#
#                                               content
#  0  # Buchhaltung und Rechnungsverwaltung\n\nDie G...  ,
#  'relationships':     id                           source                           target  \
#  0    3          DIENSTREISE IST GEPLANT                      BUCHHALTUNG
#  1    6          LANDESREISEKOSTENGESETZ                DIENSTREISEANTRAG
#  2    8                DIENSTREISEANTRAG                      BUCHHALTUNG
#  3    9          DIENSTREISE IST GEPLANT          LANDESREISEKOSTENGESETZ
#  4   19          LANDESREISEKOSTENGESETZ  REISEKOSTENABRECHNUNG_ERSTELLEN
#  5   20          LANDESREISEKOSTENGESETZ         DIENSTREISEANTRAG_SENDEN
#  6   18          LANDESREISEKOSTENGESETZ             DIENSTREISEANTRETTEN
#  7   21                      BUCHHALTUNG              RECHNUNGSVERWALTUNG
#  8   23                      BUCHHALTUNG                             ENDE
#  9   15  REISEKOSTENABRECHNUNG_ERSTELLEN         DIENSTREISEANTRAG_SENDEN
#  10  14             DIENSTREISEANTRETTEN  REISEKOSTENABRECHNUNG_ERSTELLEN
#  11  16         DIENSTREISEANTRAG_SENDEN         DIENSTREISEANTRAG_PRÜFEN
#  12  22              RECHNUNGSVERWALTUNG                             ENDE
#  13  17         DIENSTREISEANTRAG_PRÜFEN            RÜCKFRAGE_DURCHFÜHREN
#  14   1                PERSONALABTEILUNG                      BUCHHALTUNG
#  15   2          DIENSTREISE IST GEPLANT                PERSONALABTEILUNG
#  16   7                DIENSTREISEANTRAG                PERSONALABTEILUNG
#  17   0                  DIENSTREISENDER                PERSONALABTEILUNG
#  18   5                     VORGESETZTEN                PERSONALABTEILUNG
#
#                                            description weight links  in_context
#  0   Die Buchhaltung ist beteiligt an der Rechnungs...    1.0     4        True
#  1   Das Landesreisekostengesetz ist der rechtliche...    5.0     5        True
#  2   Der Dienstreiseantrag wird an die Buchhaltung ...    5.0     4        True
#  3   Das Landesreisekostengesetz ist der rechtliche...    1.0     5        True
#  4   Das Gesetz legt die Anforderungen für die Erst...    7.0     5        True
#  5          Die Abrechnung muss dem Gesetz entsprechen    1.0     5        True
#  6   Das Gesetz regelt die Voraussetzungen für die ...    7.0     5        True
#  7   Buchhaltung und Rechnungsverwaltung sind verwa...    7.0     4        True
#  8   Buchhaltung ist an der Ausführung von Prozesse...    1.0     4        True
#  9   Die gesendeten Dokumente umfassen die erstellt...    9.0     2        True
#  10  Die Erstellung der Reisekostenabrechnung folgt...    9.0     2        True
#  11  Die Personalabteilung prüft die eingegangenen ...    9.0     1        True
#  12  Rechnungsverwaltung ist an der Ausführung von ...    6.0     1        True
#  13  Eine Rückfrage wird durchgeführt, um unklare P...    9.0     1        True
#  14  Die Personalabteilung ist für die Weiterleitun...    7.0     5        True
#  15  Die Personalabteilung ist verantwortlich für d...    5.0     5        True
#  16  Die Personalabteilung prüft und bearbeitet den...    5.0     5        True
#  17  Der Dienstreisende sendet Rechnungen mit Kopie...   10.0     5        True
#  18  Die Vorgesetzten sind für die Genehmigung der ...    4.0     5        True  ,
#  'claims': Empty DataFrame
#  Columns: [in_context]
#  Index: [],
#  'entities':     id                           entity  \
#  0   16            RÜCKFRAGE_DURCHFÜHREN
#  1    3          DIENSTREISE IST GEPLANT
#  2   15         DIENSTREISEANTRAG_PRÜFEN
#  3   18                             ENDE
#  4   14         DIENSTREISEANTRAG_SENDEN
#  5   12             DIENSTREISEANTRETTEN
#  6   17              RECHNUNGSVERWALTUNG
#  7    6                DIENSTREISEANTRAG
#  8   13  REISEKOSTENABRECHNUNG_ERSTELLEN
#  9    4                     VORGESETZTEN
#  10   5          LANDESREISEKOSTENGESETZ
#  11   0                  DIENSTREISENDER
#  12   2                      BUCHHALTUNG
#
#                                            description number of relationships  \
#  0   Das Ereignis der Rückfrage zur Klärung von Unk...                       1
#  1   Das Ereignis markiert den Beginn der Dienstrei...                       3
#  2   Das Ereignis der Prüfung des Dienstreiseantrag...                       2
#  3   Ende ist ein Ereignis, das den Abschluss eines...                       2
#  4   Das Ereignis der Übermittlung des Dienstreisea...                       3
#  5   Das Ereignis der Beantragung und Vorbereitung ...                       2
#  6   Rechnungsverwaltung bezieht sich auf die Abtei...                       2
#  7   Der Dienstreiseantrag ist ein dokumentarisches...                       3
#  8   Das Ereignis der Erstellung der Reisekostenabr...                       3
#  9   Die Vorgesetzten sind die Personen, die den Di...                       1
#  10  Das Landesreisekostengesetz ist ein gesetzlich...                       5
#  11  Die Dienstreisende ist das Department, das für...                       1
#  12  Die Buchhaltung ist ein zentrales Department i...                       5
#
#      in_context
#  0         True
#  1         True
#  2         True
#  3         True
#  4         True
#  5         True
#  6         True
#  7         True
#  8         True
#  9         True
#  10        True
#  11        True
#  12        True  ,
#  'sources':   id                                               text
#  0  2   <bpmn:targetRef>Property_1n3mfdc</bpmn:target...
#  1  1   die Personalabteilung senden">\n      <bpmn:i...
#  2  3  pmn:outgoing>Flow_0fbjs6a</bpmn:outgoing>\n   ...
#  3  0  <?xml version="1.0" encoding="UTF-8"?>\n<bpmn:...}

# %%
queries = ["Wie heißt dieser Prozess?","Wenn ich mich gerade vor einer Dienstreise befinde, was gilt dann für mich zu beachten?",
           "Welcher Schritt kommt direkt nach 'Dienstreise antreten' und wer führt ihn aus?", "Welche Dokumente spielen im laufe des Prozesses eine Rolle und für wen?"]
responses = []
for i, query in enumerate(queries):
    response, context = await api.local_search(
        config=graphrag_config,
        entities=entities,
        communities=communities,
        community_reports=community_reports,
        text_units= text_unit_df,
        relationships= relationships,
        covariates = None,
        community_level=2,
        response_type="Kurze präzise Antwort auf Deutsch",
        query=query
    )
    responses.append(response)
responses
# Out:
# ['Der Prozess wird im Kontext der Daten nicht explizit benannt, ist jedoch eng mit der **Dienstreiseplanung** und der **Finanzverwaltung** verbunden. Er umfasst Schritte wie die Beantragung einer Dienstreise, Prüfung durch die Personalabteilung, Reisekostenabrechnung und Buchhaltung. \n\n[Daten: Entities (3, 6, 17), Relationships (3, 8, 21)]',
#  'Wenn Sie sich vor einer Dienstreise befinden, sind folgende Punkte zu beachten:  \n1. **Dienstreiseantrag erstellen**: Füllen Sie den Antrag aus und lassen Sie ihn von Vertreter:in und Vorgesetzten unterschreiben [Daten: DIENSTREISEANTRAG (6), VORGESETZTEN (4)].  \n2. **Kostenregelungen prüfen**: Stellen Sie sicher, dass die Reise im Einklang mit dem **Landesreisekostengesetz** (5) erfolgt, da dieses die Kostenregelungen festlegt [Daten: LANDESREISEKOSTENGESETZ (5, 6, 9, 18)].  \n3. **Dokumente bereitstellen**: Senden Sie den Antrag sowie Rechnungen und Belege an die **Personalabteilung** (1), die die Prüfung übernimmt [Daten: DIENSTREISEANTRETTEN (0), DIENSTREISEANTRAG_SENDEN (14)].  \n4. **Reisekostenabrechnung erstellen**: Dokumentieren Sie die Reisekosten nach der Reise, wobei das Gesetz die Anforderungen für die Abrechnung vorgibt [Daten: LANDESREISEKOSTENGESETZ (19), REISEKOSTENABRECHNUNG_ERSTELLEN (15)].  \n5. **Korrekturen und Rückfragen**: Bei Unklarheiten wird eine Rückfrage durchgeführt, um die Rechnung zu prüfen [Daten: RÜCKFRAGE_DURCHFÜHREN (17)].  \n6. **Buchhaltung beteiligen**: Rechnungen werden an die Buchhaltung weitergeleitet, um die Finanzbearbeitung zu ermöglichen [Daten: PERSONALABTEILUNG (1), BUCHHALTUNG (1)].  \n\nDiese Schritte sind im Prozess definiert, um Compliance mit internen Richtlinien und gesetzlichen Vorgaben zu gewährleisten.',
#  'Der Schritt, der direkt nach „Dienstreise antreten“ folgt, ist die **Erstellung der Reisekostenabrechnung** [Daten: Beziehungen (14), Quellen (2)]. Dieser Schritt wird von der **Personalabteilung** durchgeführt, da sie für die Prüfung und Weiterleitung von Rechnungen sowie die Abrechnung von Reisekosten verantwortlich ist [Daten: Beziehungen (1), Entities (6)].',
#  'Die folgenden Dokumente spielen im Prozess eine Rolle und sind für bestimmte Abteilungen relevant:  \n\n1. **Dienstreiseantrag (DIENSTREISEANTRAG)**  \n   - Wird von der **Personalabteilung** (ID 6) bearbeitet und geprüft [Daten: Beziehungen (7, 15)].  \n   - An die **Buchhaltung** (ID 2) weitergeleitet, um Rechnungen zu prüfen [Daten: Beziehungen (8)].  \n\n2. **Reisekostenabrechnung erstellen (REISEKOSTENABRECHNUNG_ERSTELLEN)**  \n   - Folgt der Beantragung der Dienstreise (DIENSTREISEANTRETTEN) und wird an die **Personalabteilung** (ID 1) gesendet [Daten: Beziehungen (14, 15)].  \n   - Muss dem **Landesreisekostengesetz** (ID 6) entsprechen [Daten: Beziehungen (19, 20)].  \n\n3. **Landesreisekostengesetz (LANDESREISEKOSTENGESETZ)**  \n   - Legt die rechtlichen Rahmenbedingungen für Dienstreisen fest und gilt für die **Personalabteilung**, **Buchhaltung** und **Rechnungsverwaltung** [Daten: Beziehungen (9, 19, 20)].  \n\n4. **Rechnungen**  \n   - Werden von der **Dienstreisende** (ID 0) an die **Personalabteilung** gesendet [Daten: Beziehungen (0)] und anschließend an die **Buchhaltung** weitergeleitet [Daten: Beziehungen (1, 21)].  \n\nDiese Dokumente sind zentral für die Zusammenarbeit zwischen den Abteilungen und werden durch rechtliche Vorgaben (Landesreisekostengesetz) gesteuert.']
